# %% [markdown]
# # Day 3 - Pandas

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 10.4/10.4 MB 7.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Data Structures
# ### 1. Series

# %%
s1 = pd.Series([12, 45, 89, 300])

# %%
s1
# Out:
# 0     12
# 1     45
# 2     89
# 3    300
# dtype: int64

# %%
s2 = pd.Series([200, 456, 651, 1000], index=['North', 'South', 'East', 'West'])

# %%
s2
# Out:
# North     200
# South     456
# East      651
# West     1000
# dtype: int64

# %%
s2.index
# Out:
# Index(['North', 'South', 'East', 'West'], dtype='object')

# %%
s2.sum()
# Out:
# 2307

# %%
s2.min()
# Out:
# 200

# %%
s2.size
# Out:
# 4

# %%
s2.ndim
# Out:
# 1

# %%
s2
# Out:
# North     200
# South     456
# East      651
# West     1000
# dtype: int64

# %%
s3 = pd.Series([1, 10, 0, 5000], index=['North', 'West', 'East', 'South'])

# %%
s3
# Out:
# North       1
# West       10
# East        0
# South    5000
# dtype: int64

# %%
s2 + s3
# Out:
# East      651
# North     201
# South    5456
# West     1010
# dtype: int64

# %%
s4 = pd.Series([1, 10, 0, 5000], index=['North', 'Northern-East', 'East', 'South'])

# %%
s4
# Out:
# North               1
# Northern-East      10
# East                0
# South            5000
# dtype: int64

# %%
s3
# Out:
# North       1
# West       10
# East        0
# South    5000
# dtype: int64

# %%
s3 + s4
# Out:
# East                 0.0
# North                2.0
# Northern-East        NaN
# South            10000.0
# West                 NaN
# dtype: float64

# %%
s3.add(s4, fill_value=0)
# Out:
# East                 0.0
# North                2.0
# Northern-East       10.0
# South            10000.0
# West                10.0
# dtype: float64

# %%
s5 = s3 + s4

# %%
s5
# Out:
# East                 0.0
# North                2.0
# Northern-East    12000.0
# South            10000.0
# West             12000.0
# dtype: float64

# %%
s5.fillna(12000, inplace=True)

# %%
s5
# Out:
# East                 0.0
# North                2.0
# Northern-East    12000.0
# South            10000.0
# West             12000.0
# dtype: float64

# %%
pd.Series([12, 34, 'Python'])
# Out:
# 0        12
# 1        34
# 2    Python
# dtype: object

# %%
s6 = pd.Series(['India', 'USA', 'China'])

# %%
s6
# Out:
# 0    India
# 1      USA
# 2    China
# dtype: object

# %% [markdown]
# ### 2. Data Frame

# %%
# Create a dataframe
df = pd.DataFrame({
    'Id': [101, 102, 103],
    'Name': ['Ajay', 'Sumit', 'Varun'],
    'Location': ['Kolkata', 'Bangalore', 'Hyderabad']
})

# %%
df
# Out:
#     Id   Name   Location
# 0  101   Ajay    Kolkata
# 1  102  Sumit  Bangalore
# 2  103  Varun  Hyderabad

# %%
#import a csv file

houseData = pd.read_csv(r"C:\Users\arpan\Documents\python-training-edureka\house.csv")

# %%
houseData
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 0    1790         2          2       2    No         East  114300
# 1    2030         4          2       3    No         East  114200
# 2    1740         3          2       1    No         East  114800
# 3    1980         3          2       3    No         East   94700
# 4    2130         3          3       3    No         East  119800
# ..    ...       ...        ...     ...   ...          ...     ...
# 123  1900         3          3       3   Yes         East  119700
# 124  2160         4          3       3   Yes         East  147900
# 125  2070         2          2       2    No        North  113500
# 126  2020         3          3       1    No         West  149900
# 127  2250         3          3       4    No        North  124600
#
# [128 rows x 7 columns]

# %%
houseData.head()
# Out:
#    SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 0  1790         2          2       2    No         East  114300
# 1  2030         4          2       3    No         East  114200
# 2  1740         3          2       1    No         East  114800
# 3  1980         3          2       3    No         East   94700
# 4  2130         3          3       3    No         East  119800

# %%
houseData.head(10)
# Out:
#    SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 0  1790         2          2       2    No         East  114300
# 1  2030         4          2       3    No         East  114200
# 2  1740         3          2       1    No         East  114800
# 3  1980         3          2       3    No         East   94700
# 4  2130         3          3       3    No         East  119800
# 5  1780         3          2       2    No        North  114600
# 6  1830         3          3       3   Yes         West  151600
# 7  2160         4          2       2    No         West  150700
# 8  2110         4          2       3    No         East  119200
# 9  1730         3          3       3    No         East  104000

# %%
houseData.tail()
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 123  1900         3          3       3   Yes         East  119700
# 124  2160         4          3       3   Yes         East  147900
# 125  2070         2          2       2    No        North  113500
# 126  2020         3          3       1    No         West  149900
# 127  2250         3          3       4    No        North  124600

# %%
houseData.tail(10)
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 118  1950         3          2       3   Yes        North  150200
# 119  1920         2          2       4    No        North  109700
# 120  1930         2          3       3    No        North  110400
# 121  1930         3          3       3    No         East  105600
# 122  2060         2          2       1   Yes         East  144800
# 123  1900         3          3       3   Yes         East  119700
# 124  2160         4          3       3   Yes         East  147900
# 125  2070         2          2       2    No        North  113500
# 126  2020         3          3       1    No         West  149900
# 127  2250         3          3       4    No        North  124600

# %%
houseData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SqFt          128 non-null    int64
#  1   Bedrooms      128 non-null    int64
#  2   Bathrooms     128 non-null    int64
#  3   Offers        128 non-null    int64
#  4   Brick         128 non-null    object
#  5   Neighborhood  128 non-null    object
#  6   Price         128 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 7.1+ KB

# %%
houseData.describe()
# Out:
#               SqFt    Bedrooms   Bathrooms      Offers          Price
# count   128.000000  128.000000  128.000000  128.000000     128.000000
# mean   2000.937500    3.023438    2.445312    2.578125  130427.343750
# std     211.572431    0.725951    0.514492    1.069324   26868.770371
# min    1450.000000    2.000000    2.000000    1.000000   69100.000000
# 25%    1880.000000    3.000000    2.000000    2.000000  111325.000000
# 50%    2000.000000    3.000000    2.000000    3.000000  125950.000000
# 75%    2140.000000    3.000000    3.000000    3.000000  148250.000000
# max    2590.000000    5.000000    4.000000    6.000000  211200.000000

# %%
houseData.describe(include='O')
# Out:
#        Brick Neighborhood
# count    128          128
# unique     2            3
# top       No         East
# freq      86           45

# %%
houseData.columns
# Out:
# Index(['SqFt', 'Bedrooms', 'Bathrooms', 'Offers', 'Brick', 'Neighborhood',
#        'Price'],
#       dtype='object')

# %%
# Reference a column
houseData.Price
# Out:
# 0      114300
# 1      114200
# 2      114800
# 3       94700
# 4      119800
#         ...
# 123    119700
# 124    147900
# 125    113500
# 126    149900
# 127    124600
# Name: Price, Length: 128, dtype: int64

# %%
houseData['Price']
# Out:
# 0      114300
# 1      114200
# 2      114800
# 3       94700
# 4      119800
#         ...
# 123    119700
# 124    147900
# 125    113500
# 126    149900
# 127    124600
# Name: Price, Length: 128, dtype: int64

# %%
# subset data
houseData[['Price', 'SqFt']]
# Out:
#       Price  SqFt
# 0    114300  1790
# 1    114200  2030
# 2    114800  1740
# 3     94700  1980
# 4    119800  2130
# ..      ...   ...
# 123  119700  1900
# 124  147900  2160
# 125  113500  2070
# 126  149900  2020
# 127  124600  2250
#
# [128 rows x 2 columns]

# %%
houseData.Price.mean()
# Out:
# 130427.34375

# %%
#vadd a new column
houseData['Country'] = 'India'

# %%
houseData
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country
# 0    1790         2          2       2    No         East  114300   India
# 1    2030         4          2       3    No         East  114200   India
# 2    1740         3          2       1    No         East  114800   India
# 3    1980         3          2       3    No         East   94700   India
# 4    2130         3          3       3    No         East  119800   India
# ..    ...       ...        ...     ...   ...          ...     ...     ...
# 123  1900         3          3       3   Yes         East  119700   India
# 124  2160         4          3       3   Yes         East  147900   India
# 125  2070         2          2       2    No        North  113500   India
# 126  2020         3          3       1    No         West  149900   India
# 127  2250         3          3       4    No        North  124600   India
#
# [128 rows x 8 columns]

# %%
# conditionally populate values in a column
import numpy as np

# %%
houseData['Category']=np.where(houseData.Price >= 140000, 'High', 'Low')

# %%
houseData.head()
# Out:
#    SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 0  1790         2          2       2    No         East  114300   India
# 1  2030         4          2       3    No         East  114200   India
# 2  1740         3          2       1    No         East  114800   India
# 3  1980         3          2       3    No         East   94700   India
# 4  2130         3          3       3    No         East  119800   India
#
#   Category
# 0      Low
# 1      Low
# 2      Low
# 3      Low
# 4      Low

# %%
# pd.read_excel("filepath/file_name.xlsx", sheet_name="sheet1")

# %%
houseData.head(2)
# Out:
#    SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 0  1790         2          2       2    No         East  114300   India
# 1  2030         4          2       3    No         East  114200   India
#
#   Category
# 0      Low
# 1      Low

# %%
houseData.Neighborhood.unique()
# Out:
# array(['East', 'North', 'West'], dtype=object)

# %%
houseData.Neighborhood.value_counts()
# Out:
# East     45
# North    44
# West     39
# Name: Neighborhood, dtype: int64

# %%
pd.crosstab(houseData.Neighborhood, houseData.Brick)
# Out:
# Brick         No  Yes
# Neighborhood
# East          26   19
# North         37    7
# West          23   16

# %%
# Exporting
res = pd.crosstab(houseData.Neighborhood, houseData.Brick)

# %%
res
# Out:
# Brick         No  Yes
# Neighborhood
# East          26   19
# North         37    7
# West          23   16

# %%
# !pip install openpyxl
# Out:
# ...
#      -------------------------------------- 242.1/242.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
res.to_excel("report.xlsx")

# %%
res.to_html("report.html")

# %%
pd.read_html("report.html")
# Out:
# [         Brick                 No                Yes
#    Neighborhood Unnamed: 1_level_1 Unnamed: 2_level_1
#  0         East                 26                 19
#  1        North                 37                  7
#  2         West                 23                 16]

# %%
# Filtering data
houseData[houseData.Neighborhood=='East']
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 0    1790         2          2       2    No         East  114300   India
# 1    2030         4          2       3    No         East  114200   India
# 2    1740         3          2       1    No         East  114800   India
# 3    1980         3          2       3    No         East   94700   India
# 4    2130         3          3       3    No         East  119800   India
# 8    2110         4          2       3    No         East  119200   India
# 9    1730         3          3       3    No         East  104000   India
# 10   2030         3          2       3   Yes         East  132500   India
# 11   1870         2          2       2   Yes         East  123000   India
# 16   2190         3          3       4   Yes         East  147100   India
# 18   1700         2          2       1   Yes         East  111400   India
# 20   1790         3          2       3    No         East  116200   India
# ...

# %%
# Filtering data
houseData[(houseData.Neighborhood=='East') & (houseData.Brick=='Yes')]
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 10   2030         3          2       3   Yes         East  132500   India
# 11   1870         2          2       2   Yes         East  123000   India
# 16   2190         3          3       4   Yes         East  147100   India
# 18   1700         2          2       1   Yes         East  111400   India
# 24   2210         4          3       2   Yes         East  156400   India
# 32   2250         3          3       3   Yes         East  135000   India
# 33   2280         5          3       4   Yes         East  139600   India
# 43   1920         3          2       1   Yes         East  154000   India
# 50   2100         3          2       3   Yes         East  151100   India
# 55   1720         2          2       2   Yes         East  125700   India
# 56   2190         3          2       3   Yes         East  140900   India
# 80   2190         3          3       4   Yes         East  143400   India
# ...

# %%
houseData[houseData.Location.isin(['East', 'North'])]
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Location   Price
# 93   2080         3          3       2    No     East  157100
# 24   2210         4          3       2   Yes     East  156400
# 43   1920         3          2       1   Yes     East  154000
# 67   2040         4          3       3    No     East  151900
# 50   2100         3          2       3   Yes     East  151100
# ..    ...       ...        ...     ...   ...      ...     ...
# 47   2050         3          2       6    No    North   90300
# 17   1990         3          3       4    No    North   83600
# 104  1910         3          2       4    No     East   82300
# 54   1650         3          2       3    No    North   81300
# 28   1600         2          2       3    No    North   69100
#
# [89 rows x 7 columns]

# %%
# sorting
houseData.sort_values('Price', ascending=False, inplace=True)

# %%
houseData
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 103  2440         4          3       3   Yes         West  211200   India
# 116  2290         5          4       1   Yes         West  199500   India
# 85   2250         4          3       2   Yes         West  188300   India
# 29   2040         4          3       1   Yes         West  188000   India
# 81   2140         4          3       2   Yes         West  184300   India
# ..    ...       ...        ...     ...   ...          ...     ...     ...
# 47   2050         3          2       6    No        North   90300   India
# 17   1990         3          3       4    No        North   83600   India
# 104  1910         3          2       4    No         East   82300   India
# 54   1650         3          2       3    No        North   81300   India
# 28   1600         2          2       3    No        North   69100   India
#
#     Category
# 103     High
# 116     High
# 85      High
# 29      High
# ...

# %%
# Grouping and Aggregation
houseData.head(1)
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 103  2440         4          3       3   Yes         West  211200   India
#
#     Category
# 103     High

# %%
grps = houseData.groupby('Neighborhood')

# %%
grps.groups
# Out:
# {'East': [93, 24, 43, 67, 50, 124, 83, 16, 122, 80, 56, 33, 102, 32, 107, 96, 10, 97, 73, 55, 114, 112, 101, 11, 63, 4, 123, 8, 108, 91, 20, 48, 2, 0, 1, 18, 109, 40, 121, 42, 9, 45, 27, 3, 104], 'North': [118, 25, 53, 46, 88, 13, 66, 127, 78, 34, 117, 36, 52, 35, 113, 111, 5, 21, 125, 31, 110, 65, 120, 119, 106, 39, 49, 72, 75, 23, 100, 86, 12, 115, 61, 89, 68, 22, 51, 84, 47, 17, 54, 28], 'West': [103, 116, 85, 29, 81, 30, 60, 14, 77, 87, 99, 19, 70, 44, 69, 82, 62, 94, 71, 59, 95, 57, 6, 7, 126, 37, 105, 15, 98, 74, 79, 90, 92, 58, 26, 41, 38, 64, 76]}

# %%
grps.get_group('East')
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Country  \
# 93   2080         3          3       2    No         East  157100   India
# 24   2210         4          3       2   Yes         East  156400   India
# 43   1920         3          2       1   Yes         East  154000   India
# 67   2040         4          3       3    No         East  151900   India
# 50   2100         3          2       3   Yes         East  151100   India
# 124  2160         4          3       3   Yes         East  147900   India
# 83   2410         3          3       2    No         East  147700   India
# 16   2190         3          3       4   Yes         East  147100   India
# 122  2060         2          2       1   Yes         East  144800   India
# 80   2190         3          3       4   Yes         East  143400   India
# 56   2190         3          2       3   Yes         East  140900   India
# 33   2280         5          3       4   Yes         East  139600   India
# ...

# %%
houseData.groupby('Neighborhood')['Price'].mean()
# Out:
# Neighborhood
# East     125231.111111
# North    110154.545455
# West     159294.871795
# Name: Price, dtype: float64

# %%
houseData.groupby('Neighborhood')['Price'].agg(['min', 'max', 'mean', 'std', 'var'])
# Out:
#                  min     max           mean           std           var
# Neighborhood
# East           82300  157100  125231.111111  17866.052398  3.191958e+08
# North          69100  150200  110154.545455  15973.880636  2.551649e+08
# West          129800  211200  159294.871795  19781.729326  3.913168e+08

# %%
houseData.groupby('Neighborhood')[['Price', 'SqFt']].agg(['min', 'max', 'mean', 'std', 'var'])
# Out:
#                Price                                                     SqFt  \
#                  min     max           mean           std           var   min
# Neighborhood
# East           82300  157100  125231.111111  17866.052398  3.191958e+08  1560
# North          69100  150200  110154.545455  15973.880636  2.551649e+08  1450
# West          129800  211200  159294.871795  19781.729326  3.913168e+08  1720
#
#
#                max         mean         std           var
# Neighborhood
# East          2440  2014.000000  201.363534  40547.272727
# North         2290  1916.818182  198.081176  39236.152220
# West          2590  2080.769231  208.129320  43317.813765

# %%
res = houseData.groupby('Neighborhood')[['Price', 'SqFt']].agg({'Price': [np.mean, np.std], 'SqFt': np.sum})
res
# Out:
#                       Price                 SqFt
#                        mean           std    sum
# Neighborhood
# East          125231.111111  17866.052398  90630
# North         110154.545455  15973.880636  84340
# West          159294.871795  19781.729326  81150

# %%
res.columns
# Out:
# MultiIndex([('Price', 'mean'),
#             ('Price',  'std'),
#             ( 'SqFt',  'sum')],
#            )

# %%
res.index
# Out:
# Index(['East', 'North', 'West'], dtype='object', name='Neighborhood')

# %%
res
# Out:
#                       Price                 SqFt
#                        mean           std    sum
# Neighborhood
# East          125231.111111  17866.052398  90630
# North         110154.545455  15973.880636  84340
# West          159294.871795  19781.729326  81150

# %%
res.reset_index
res
# Out:
#                       Price                 SqFt
#                        mean           std    sum
# Neighborhood
# East          125231.111111  17866.052398  90630
# North         110154.545455  15973.880636  84340
# West          159294.871795  19781.729326  81150

# %%
# remove a column
houseData.head()
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 103  2440         4          3       3   Yes         West  211200
# 116  2290         5          4       1   Yes         West  199500
# 85   2250         4          3       2   Yes         West  188300
# 29   2040         4          3       1   Yes         West  188000
# 81   2140         4          3       2   Yes         West  184300

# %%
houseData.drop(columns='Country')
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price Category
# 103  2440         4          3       3   Yes         West  211200     High
# 116  2290         5          4       1   Yes         West  199500     High
# 85   2250         4          3       2   Yes         West  188300     High
# 29   2040         4          3       1   Yes         West  188000     High
# 81   2140         4          3       2   Yes         West  184300     High
# ..    ...       ...        ...     ...   ...          ...     ...      ...
# 47   2050         3          2       6    No        North   90300      Low
# 17   1990         3          3       4    No        North   83600      Low
# 104  1910         3          2       4    No         East   82300      Low
# 54   1650         3          2       3    No        North   81300      Low
# 28   1600         2          2       3    No        North   69100      Low
#
# [128 rows x 8 columns]

# %%
houseData.drop(columns=['Country', 'Category'], inplace=True)

# %%
houseData.head()
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood   Price
# 103  2440         4          3       3   Yes         West  211200
# 116  2290         5          4       1   Yes         West  199500
# 85   2250         4          3       2   Yes         West  188300
# 29   2040         4          3       1   Yes         West  188000
# 81   2140         4          3       2   Yes         West  184300

# %%
# rename a column
houseData.rename(columns={'Neighborhood': 'Location'}, inplace=True)

# %%
houseData.head(1)
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Location   Price
# 103  3000         4          3       3   Yes     West  211200

# %%
# updating a cell value
houseData.iloc[0, 0] = 3000

# %%
houseData.head(1)
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Location   Price
# 103  3000         4          3       3   Yes     West  211200

# %%
houseData.loc[103, 'SqFt']
# Out:
# 3000

# %% [markdown]
# ### Merging, Joining and Concat

# %%
data1 = pd.read_csv("diabetes_data1.csv")
data2 = pd.read_csv("diabetes_data2.csv")
data_new_row = pd.read_csv("diabetes_data1_newRows.csv")

# %%
data1.head(1)
# Out:
#   PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome
# 0    PT1001            6      148                     0.627        1

# %%
data2.head(1)
# Out:
#   PatientID   BMI  Age
# 0    PT1001  33.6   50

# %%
data_new_row.head(1)
# Out:
#   PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome
# 0    PT1022            4       95                     0.161        1

# %%
# Merge
data1.PatientID.unique()
# Out:
# array(['PT1001', 'PT1002', 'PT1003', 'PT1004', 'PT1005', 'PT1006',
#        'PT1007', 'PT1008', 'PT1009', 'PT1010', 'PT1011', 'PT1012',
#        'PT1013', 'PT1014', 'PT1015', 'PT1016', 'PT1017', 'PT1018',
#        'PT1019', 'PT1020'], dtype=object)

# %%
data2.PatientID.unique()
# Out:
# array(['PT1001', 'PT1002', 'PT1003', 'PT1004', 'PT1005', 'PT1021',
#        'PT1030'], dtype=object)

# %%
pd.merge(data1, data2, left_on='PatientID', right_on='PatientID')
# Out:
#   PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome   BMI  \
# 0    PT1001            6      148                     0.627        1  33.6
# 1    PT1002            1       85                     0.351        0  26.6
# 2    PT1003            8      183                     0.672        1  23.3
# 3    PT1004            1       89                     0.167        0  28.1
# 4    PT1005            0      137                     2.288        1  43.1
#
#    Age
# 0   50
# 1   31
# 2   32
# 3   21
# 4   33

# %%
pd.merge(data1, data2, on='PatientID', how="left")
# Out:
#    PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome   BMI  \
# 0     PT1001            6      148                     0.627        1  33.6
# 1     PT1002            1       85                     0.351        0  26.6
# 2     PT1003            8      183                     0.672        1  23.3
# 3     PT1004            1       89                     0.167        0  28.1
# 4     PT1005            0      137                     2.288        1  43.1
# 5     PT1006            5      116                     0.201        0   NaN
# 6     PT1007            3       78                     0.248        1   NaN
# 7     PT1008           10      115                     0.134        0   NaN
# 8     PT1009            2      197                     0.158        1   NaN
# 9     PT1010            8      125                     0.232        1   NaN
# 10    PT1011            4      110                     0.191        0   NaN
# ...

# %%
pd.merge(data1, data2, on='PatientID', how="right")
# Out:
#   PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome   BMI  \
# 0    PT1001          6.0    148.0                     0.627      1.0  33.6
# 1    PT1002          1.0     85.0                     0.351      0.0  26.6
# 2    PT1003          8.0    183.0                     0.672      1.0  23.3
# 3    PT1004          1.0     89.0                     0.167      0.0  28.1
# 4    PT1005          0.0    137.0                     2.288      1.0  43.1
# 5    PT1021          NaN      NaN                       NaN      NaN  25.6
# 6    PT1030          NaN      NaN                       NaN      NaN  31.0
#
#    Age
# 0   50
# 1   31
# 2   32
# 3   21
# 4   33
# 5   30
# 6   26

# %%
pd.merge(data1, data2, on='PatientID', how="outer")
# Out:
#    PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome   BMI  \
# 0     PT1001          6.0    148.0                     0.627      1.0  33.6
# 1     PT1002          1.0     85.0                     0.351      0.0  26.6
# 2     PT1003          8.0    183.0                     0.672      1.0  23.3
# 3     PT1004          1.0     89.0                     0.167      0.0  28.1
# 4     PT1005          0.0    137.0                     2.288      1.0  43.1
# 5     PT1006          5.0    116.0                     0.201      0.0   NaN
# 6     PT1007          3.0     78.0                     0.248      1.0   NaN
# 7     PT1008         10.0    115.0                     0.134      0.0   NaN
# 8     PT1009          2.0    197.0                     0.158      1.0   NaN
# 9     PT1010          8.0    125.0                     0.232      1.0   NaN
# 10    PT1011          4.0    110.0                     0.191      0.0   NaN
# ...

# %%
# pd.merge(df1, df2, on=['col1', 'col2', 'col3'])

# %%
# pd.merge(df1, df2, left_on=['col1', 'col2', 'col3'], left_on=['c1', 'c2', 'c3'])

# %%
data_new_row
# Out:
#   PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome
# 0    PT1022            4       95                     0.161        1
# 1    PT1023            6      137                     0.151        0
# 2    PT1024            5      136                     0.286        1
# 3    PT1025            9       72                     0.280        0
# 4    PT1026            5      168                     0.135        1

# %%
pd.concat([data1, data_new_row], axis=0)
# Out:
#    PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome
# 0     PT1001            6      148                     0.627        1
# 1     PT1002            1       85                     0.351        0
# 2     PT1003            8      183                     0.672        1
# 3     PT1004            1       89                     0.167        0
# 4     PT1005            0      137                     2.288        1
# 5     PT1006            5      116                     0.201        0
# 6     PT1007            3       78                     0.248        1
# 7     PT1008           10      115                     0.134        0
# 8     PT1009            2      197                     0.158        1
# 9     PT1010            8      125                     0.232        1
# 10    PT1011            4      110                     0.191        0
# 11    PT1012           10      168                     0.537        1
# ...

# %%
pd.concat([data1, data_new_row], axis=0, ignore_index=True)
# Out:
#    PatientID  Pregnancies  Glucose  DiabetesPedigreeFunction  Outcome
# 0     PT1001            6      148                     0.627        1
# 1     PT1002            1       85                     0.351        0
# 2     PT1003            8      183                     0.672        1
# 3     PT1004            1       89                     0.167        0
# 4     PT1005            0      137                     2.288        1
# 5     PT1006            5      116                     0.201        0
# 6     PT1007            3       78                     0.248        1
# 7     PT1008           10      115                     0.134        0
# 8     PT1009            2      197                     0.158        1
# 9     PT1010            8      125                     0.232        1
# 10    PT1011            4      110                     0.191        0
# 11    PT1012           10      168                     0.537        1
# ...

# %%
df = pd.read_csv("diabetes_sample.csv")

# %%
df
# Out:
#    PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0     PT1001            6      148             72             35    250.0
# 1     PT1002            1       85             66             29    300.0
# 2     PT1003            8      183             64              0      NaN
# 3     PT1004            1       89             66             23     94.0
# 4     PT1005            0      137             40             35    168.0
# 5     PT1005            0      137             40             35    168.0
# 6     PT1006            3       78             50             32     88.0
# 7     PT1007           10      115              0              0    400.0
# 8     PT1008            2      197             70             45    543.0
# 9     PT1009            8      125             96              0      0.0
# 10    PT1009            4      110             92              0      0.0
# 11    PT1011           10      168             74              0      0.0
# ...

# %%
df.isna().any()
# Out:
# PatientID                   False
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                      True
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# PatientID                   0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     1
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# drop row with missing value
df_new = df.dropna()

# %%
df_new
# Out:
#    PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0     PT1001            6      148             72             35    250.0
# 1     PT1002            1       85             66             29    300.0
# 3     PT1004            1       89             66             23     94.0
# 4     PT1005            0      137             40             35    168.0
# 5     PT1005            0      137             40             35    168.0
# 6     PT1006            3       78             50             32     88.0
# 7     PT1007           10      115              0              0    400.0
# 8     PT1008            2      197             70             45    543.0
# 9     PT1009            8      125             96              0      0.0
# 10    PT1009            4      110             92              0      0.0
# 11    PT1011           10      168             74              0      0.0
# 12    PT1012           10      139             80              0      0.0
# ...

# %%
df.shape
# Out:
# (15, 10)

# %%
df_new.shape
# Out:
# (14, 10)

# %%
df.dropna(subset=['Insulin'])
# Out:
#    PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0     PT1001            6      148             72             35    250.0
# 1     PT1002            1       85             66             29    300.0
# 3     PT1004            1       89             66             23     94.0
# 4     PT1005            0      137             40             35    168.0
# 5     PT1005            0      137             40             35    168.0
# 6     PT1006            3       78             50             32     88.0
# 7     PT1007           10      115              0              0    400.0
# 8     PT1008            2      197             70             45    543.0
# 9     PT1009            8      125             96              0      0.0
# 10    PT1009            4      110             92              0      0.0
# 11    PT1011           10      168             74              0      0.0
# 12    PT1012           10      139             80              0      0.0
# ...

# %%
df.Insulin.fillna(df.Insulin.mean())
# Out:
# 0     250.000000
# 1     300.000000
# 2     216.571429
# 3      94.000000
# 4     168.000000
# 5     168.000000
# 6      88.000000
# 7     400.000000
# 8     543.000000
# 9       0.000000
# 10      0.000000
# 11      0.000000
# 12      0.000000
# 13    846.000000
# 14    175.000000
# Name: Insulin, dtype: float64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#   PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 5    PT1005            0      137             40             35    168.0
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 5  43.1                     2.288   33        1

# %%
df.drop_duplicates()
# Out:
#    PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0     PT1001            6      148             72             35    250.0
# 1     PT1002            1       85             66             29    300.0
# 2     PT1003            8      183             64              0      NaN
# 3     PT1004            1       89             66             23     94.0
# 4     PT1005            0      137             40             35    168.0
# 6     PT1006            3       78             50             32     88.0
# 7     PT1007           10      115              0              0    400.0
# 8     PT1008            2      197             70             45    543.0
# 9     PT1009            8      125             96              0      0.0
# 10    PT1009            4      110             92              0      0.0
# 11    PT1011           10      168             74              0      0.0
# 12    PT1012           10      139             80              0      0.0
# ...

# %%
df.drop_duplicates(subset='Outcome')
# Out:
#   PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0    PT1001            6      148             72             35    250.0
# 1    PT1002            1       85             66             29    300.0
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  33.6                     0.627   50        1
# 1  26.6                     0.351   31        0

# %%
df.drop_duplicates(subset=['Pregnancies', 'Outcome'])
# Out:
#    PatientID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0     PT1001            6      148             72             35    250.0
# 1     PT1002            1       85             66             29    300.0
# 2     PT1003            8      183             64              0      NaN
# 4     PT1005            0      137             40             35    168.0
# 6     PT1006            3       78             50             32     88.0
# 7     PT1007           10      115              0              0    400.0
# 8     PT1008            2      197             70             45    543.0
# 10    PT1009            4      110             92              0      0.0
# 11    PT1011           10      168             74              0      0.0
# 13    PT1013            1      189             60             23    846.0
# 14    PT1014            5      166             72             19    175.0
#
#      BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.Insulin.replace(0, 10000)
# Out:
# 0       250.0
# 1       300.0
# 2         NaN
# 3        94.0
# 4       168.0
# 5       168.0
# 6        88.0
# 7       400.0
# 8       543.0
# 9     10000.0
# 10    10000.0
# 11    10000.0
# 12    10000.0
# 13      846.0
# 14      175.0
# Name: Insulin, dtype: float64

# %% [markdown]
# ## Pivot Table

# %%
houseData.head(1)
# Out:
#      SqFt  Bedrooms  Bathrooms  Offers Brick Location   Price
# 103  3000         4          3       3   Yes     West  211200

# %%
pd.pivot_table(data=houseData,index='Location',values='Price',aggfunc='mean')
# Out:
#                   Price
# Location
# East      125231.111111
# North     110154.545455
# West      159294.871795

# %%
pd.pivot_table(data=houseData,index=['Location', 'Brick'],values='Price',aggfunc='mean')
# Out:
#                         Price
# Location Brick
# East     No     117750.000000
#          Yes    135468.421053
# North    No     108583.783784
#          Yes    118457.142857
# West     No     148230.434783
#          Yes    175200.000000

# %%
pd.pivot_table(data=houseData,index=['Location', 'Brick'],columns=['Bedrooms'],values='Price',aggfunc='mean')
# Out:
# Bedrooms                    2              3              4         5
# Location Brick
# East     No     112580.000000  116988.235294  127450.000000       NaN
#          Yes    125883.333333  137470.000000  152150.000000  139600.0
# North    No     106593.333333  108335.000000  126000.000000       NaN
#          Yes    111700.000000  121160.000000            NaN       NaN
# West     No               NaN  143622.222222  151192.857143       NaN
#          Yes    158650.000000  165916.666667  184414.285714  199500.0

# %%
pd.pivot_table(data=houseData,index=['Location', 'Brick'],columns=['Bedrooms'],values='Price',aggfunc='mean',margins=True)
# Out:
# Bedrooms                    2              3              4         5  \
# Location Brick
# East     No     112580.000000  116988.235294  127450.000000       NaN
#          Yes    125883.333333  137470.000000  152150.000000  139600.0
# North    No     106593.333333  108335.000000  126000.000000       NaN
#          Yes    111700.000000  121160.000000            NaN       NaN
# West     No               NaN  143622.222222  151192.857143       NaN
#          Yes    158650.000000  165916.666667  184414.285714  199500.0
# All             115260.000000  125732.835821  154265.517241  169550.0
#
# Bedrooms                  All
# Location Brick
# East     No     117750.000000
#          Yes    135468.421053
# North    No     108583.783784
#          Yes    118457.142857
# West     No     148230.434783
#          Yes    175200.000000
# All             130427.343750
